# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = "https://economia.uol.com.br/cotacoes/bolsas"
page = urlopen(url)
html = page.read().decode("utf-8" )
soup = BeautifulSoup(html, "html.parser")

# %%
stockData = []

for trSections in soup.find("section", class_="stock-rankings").div.find_all("tr")[:10]:
    stockData.append(divSection.get_text("|").split("|"))
print(stockData)
# Out:
# [['SULA11.SA', '-5,03%', 'R$ 33,03'], ['SULA11.SA', '-5,03%', 'R$ 33,03'], ['SULA11.SA', '-5,03%', 'R$ 33,03'], ['SULA11.SA', '-5,03%', 'R$ 33,03'], ['SULA11.SA', '-5,03%', 'R$ 33,03'], ['SULA11.SA', '-5,03%', 'R$ 33,03'], ['SULA11.SA', '-5,03%', 'R$ 33,03'], ['SULA11.SA', '-5,03%', 'R$ 33,03'], ['SULA11.SA', '-5,03%', 'R$ 33,03'], ['SULA11.SA', '-5,03%', 'R$ 33,03']]
